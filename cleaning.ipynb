# %%
import pandas as pd

# %%
voting_data = pd.read_csv("data/voting_VA.csv")
voting_data
# Out:
#       Unnamed: 0  year     state state_po      county_name  county_fips  \
# 0          11161  2000  VIRGINIA       VA         ACCOMACK        51001
# 1          11162  2000  VIRGINIA       VA         ACCOMACK        51001
# 2          11163  2000  VIRGINIA       VA         ACCOMACK        51001
# 3          11164  2000  VIRGINIA       VA         ACCOMACK        51001
# 4          11165  2000  VIRGINIA       VA        ALBEMARLE        51003
# ...          ...   ...       ...      ...              ...          ...
# 3731       71966  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3732       71967  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3733       71968  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3734       71969  2020  VIRGINIA       VA  WINCHESTER CITY        51840
# 3735       71970  2020  VIRGINIA       VA  WINCHESTER CITY        51840
#
#             office       candidate       party  candidatevotes  totalvotes  \
# 0     US PRESIDENT         AL GORE    DEMOCRAT            5092       11925
# 1     US PRESIDENT  GEORGE W. BUSH  REPUBLICAN            6352       11925
# 2     US PRESIDENT     RALPH NADER       GREEN             220       11925
# 3     US PRESIDENT           OTHER       OTHER             261       11925
# 4     US PRESIDENT         AL GORE    DEMOCRAT           16255       36846
# ...            ...             ...         ...             ...         ...
# 3731  US PRESIDENT           OTHER       OTHER              24       12113
# 3732  US PRESIDENT           OTHER       OTHER               0       12113
# 3733  US PRESIDENT  DONALD J TRUMP  REPUBLICAN            2825       12113
# 3734  US PRESIDENT  DONALD J TRUMP  REPUBLICAN            2370       12113
# 3735  US PRESIDENT  DONALD J TRUMP  REPUBLICAN              26       12113
#
#        version          mode
# 0     20220315         TOTAL
# 1     20220315         TOTAL
# 2     20220315         TOTAL
# 3     20220315         TOTAL
# 4     20220315         TOTAL
# ...        ...           ...
# 3731  20220315  ELECTION DAY
# 3732  20220315   PROVISIONAL
# 3733  20220315      ABSENTEE
# 3734  20220315  ELECTION DAY
# 3735  20220315   PROVISIONAL
#
# [3736 rows x 13 columns]

# %% [markdown]
# It seems as though we have some useless columns, so let's go ahead and drop some:

# %%
cleaned_voting = voting_data.drop(columns=['Unnamed: 0', 'version', 'mode'])
cleaned_voting
# Out:
#       year     state state_po      county_name  county_fips        office  \
# 0     2000  VIRGINIA       VA         ACCOMACK        51001  US PRESIDENT
# 1     2000  VIRGINIA       VA         ACCOMACK        51001  US PRESIDENT
# 2     2000  VIRGINIA       VA         ACCOMACK        51001  US PRESIDENT
# 3     2000  VIRGINIA       VA         ACCOMACK        51001  US PRESIDENT
# 4     2000  VIRGINIA       VA        ALBEMARLE        51003  US PRESIDENT
# ...    ...       ...      ...              ...          ...           ...
# 3731  2020  VIRGINIA       VA  WINCHESTER CITY        51840  US PRESIDENT
# 3732  2020  VIRGINIA       VA  WINCHESTER CITY        51840  US PRESIDENT
# 3733  2020  VIRGINIA       VA  WINCHESTER CITY        51840  US PRESIDENT
# 3734  2020  VIRGINIA       VA  WINCHESTER CITY        51840  US PRESIDENT
# 3735  2020  VIRGINIA       VA  WINCHESTER CITY        51840  US PRESIDENT
#
#            candidate       party  candidatevotes  totalvotes
# 0            AL GORE    DEMOCRAT            5092       11925
# 1     GEORGE W. BUSH  REPUBLICAN            6352       11925
# 2        RALPH NADER       GREEN             220       11925
# 3              OTHER       OTHER             261       11925
# 4            AL GORE    DEMOCRAT           16255       36846
# ...              ...         ...             ...         ...
# 3731           OTHER       OTHER              24       12113
# 3732           OTHER       OTHER               0       12113
# 3733  DONALD J TRUMP  REPUBLICAN            2825       12113
# 3734  DONALD J TRUMP  REPUBLICAN            2370       12113
# 3735  DONALD J TRUMP  REPUBLICAN              26       12113
#
# [3736 rows x 10 columns]

# %% [markdown]
# It also feels as if we don't really need the office, state_po, or state column as we are only working with virginia data and the entire CSV only contains Virginia data, so we can remove those columns as well. Office stays as US President throughout the CSV as well.

# %%
dropped = ['office', 'state', 'state_po']
cleaned_voting.drop(dropped, axis=1,inplace=True)
cleaned_voting
# Out:
#       year      county_name  county_fips       candidate       party  \
# 0     2000         ACCOMACK        51001         AL GORE    DEMOCRAT
# 1     2000         ACCOMACK        51001  GEORGE W. BUSH  REPUBLICAN
# 2     2000         ACCOMACK        51001     RALPH NADER       GREEN
# 3     2000         ACCOMACK        51001           OTHER       OTHER
# 4     2000        ALBEMARLE        51003         AL GORE    DEMOCRAT
# ...    ...              ...          ...             ...         ...
# 3731  2020  WINCHESTER CITY        51840           OTHER       OTHER
# 3732  2020  WINCHESTER CITY        51840           OTHER       OTHER
# 3733  2020  WINCHESTER CITY        51840  DONALD J TRUMP  REPUBLICAN
# 3734  2020  WINCHESTER CITY        51840  DONALD J TRUMP  REPUBLICAN
# 3735  2020  WINCHESTER CITY        51840  DONALD J TRUMP  REPUBLICAN
#
#       candidatevotes  totalvotes
# 0               5092       11925
# 1               6352       11925
# 2                220       11925
# 3                261       11925
# 4              16255       36846
# ...              ...         ...
# 3731              24       12113
# 3732               0       12113
# 3733            2825       12113
# 3734            2370       12113
# 3735              26       12113
#
# [3736 rows x 7 columns]

# %% [markdown]
# Now let's see if we have missing values:

# %%
cleaned_voting.isnull().sum()
# Out:
# year              0
# county_name       0
# county_fips       0
# candidate         0
# party             0
# candidatevotes    0
# totalvotes        0
# dtype: int64

# %% [markdown]
# With no missing values to handle, lets observe types.

# %%
cleaned_voting.dtypes
# Out:
# year               int64
# county_name       object
# county_fips        int64
# candidate         object
# party             object
# candidatevotes     int64
# totalvotes         int64
# dtype: object

# %% [markdown]
# There isn't any conflicting types, but we can change the party to a category (may make future analysis easier)

# %%
cleaned_voting['party'] = cleaned_voting['party'].astype('category')

# %% [markdown]
# Now let's check uniqueness:

# %%
cleaned_voting['candidate'].unique()
# Out:
# array(['AL GORE', 'GEORGE W. BUSH', 'RALPH NADER', 'OTHER', 'JOHN KERRY',
#        'BARACK OBAMA', 'JOHN MCCAIN', 'MITT ROMNEY', 'HILLARY CLINTON',
#        'DONALD TRUMP', 'JOSEPH R BIDEN JR', 'JO JORGENSEN',
#        'DONALD J TRUMP'], dtype=object)

# %% [markdown]
# There seems to be two trump coluns, so let's go ahead and replace one of them.

# %%
cleaned_voting['candidate'].replace('DONALD J TRUMP', 'DONALD TRUMP', inplace=True)
cleaned_voting['candidate'].unique()
# Out:
# array(['AL GORE', 'GEORGE W. BUSH', 'RALPH NADER', 'OTHER', 'JOHN KERRY',
#        'BARACK OBAMA', 'JOHN MCCAIN', 'MITT ROMNEY', 'HILLARY CLINTON',
#        'DONALD TRUMP', 'JOSEPH R BIDEN JR', 'JO JORGENSEN'], dtype=object)

# %%
cleaned_voting['county_name'].duplicated().sum()
# Out:
# 3569

# %% [markdown]
# So there seems to be some cities with both the city and non city suffixes, which we have to standardize across both datasets (county dataset seems to also be problematic).

# %%
cleaned_voting['county_name'].replace({
    'ALEXANDRIA': 'ALEXANDRIA CITY',
    'BRISTOL': 'BRISTOL CITY',
    'BUENA VISTA': 'BUENA VISTA CITY',
    'CharlesCty': 'CHARLES CITY',
    'CHARLOTTESVILLE': 'CHARLOTTESVILLE CITY',
    'CHESAPEAKE': 'CHESAPEAKE CITY',
    'COLONIAL HEIGHTS': 'COLONIAL HEIGHTS CITY',
    'COVINGTON': 'COVINGTON CITY',
    'DANVILLE': 'DANVILLE CITY',
    'EMPORIA': 'EMPORIA CITY',
    'FAIRFAX': 'FAIRFAX CITY',
    'FALLS CHURCH': 'FALLS CHURCH CITY',
    'FREDERICKSBURG': 'FREDERICKSBURG CITY',
    'HAMPTON': 'HAMPTON CITY',
    'HARRISONBURG': 'HARRISONBURG CITY',
    'LEXINGTON': 'LEXINGTON CITY',
    'LYNCHBURG': 'LYNCHBURG CITY',
    'MANASSAS': 'MANASSAS CITY',
    'MARTINSVILLE': 'MARTINSVILLE CITY',
    'NEWPORT NEWS': 'NEWPORT NEWS CITY',
    'NORFOLK': 'NORFOLK CITY',
    'NORTON': 'NORTON CITY',
    'PETERSBURG': 'PETERSBURG CITY',
    'POQUOSON': 'POQUOSON CITY',
    'PORTSMOUTH': 'PORTSMOUTH CITY',
    'RADFORD': 'RADFORD CITY',
    'SALEM': 'SALEM CITY',
    'STAUNTON': 'STAUNTON CITY',
    'SUFFOLK': 'SUFFOLK CITY',
    'VIRGINIA BEACH': 'VIRGINIA BEACH CITY',
    'WAYNESBORO': 'WAYNESBORO CITY',
    'WILLIAMSBURG': 'WILLIAMSBURG CITY',
    'WINCHESTER': 'WINCHESTER CITY'
}, inplace=True)

cleaned_voting['county_name'].unique()
# Out:
# array(['ACCOMACK', 'ALBEMARLE', 'ALLEGHANY', 'AMELIA', 'AMHERST',
#        'APPOMATTOX', 'ARLINGTON', 'AUGUSTA', 'BATH', 'BEDFORD', 'BLAND',
#        'BOTETOURT', 'BRUNSWICK', 'BUCHANAN', 'BUCKINGHAM', 'CAMPBELL',
#        'CAROLINE', 'CARROLL', 'CHARLES CITY', 'CHARLOTTE', 'CHESTERFIELD',
#        'CLARKE', 'CRAIG', 'CULPEPER', 'CUMBERLAND', 'DICKENSON',
#        'DINWIDDIE', 'ESSEX', 'FAIRFAX CITY', 'FAUQUIER', 'FLOYD',
#        'FLUVANNA', 'FRANKLIN', 'FREDERICK', 'GILES', 'GLOUCESTER',
#        'GOOCHLAND', 'GRAYSON', 'GREENE', 'GREENSVILLE', 'HALIFAX',
#        'HANOVER', 'HENRICO', 'HENRY', 'HIGHLAND', 'ISLE OF WIGHT',
#        'JAMES CITY', 'KING AND QUEEN', 'KING GEORGE', 'KING WILLIAM',
#        'LANCASTER', 'LEE', 'LOUDOUN', 'LOUISA', 'LUNENBURG', 'MADISON',
#        'MATHEWS', 'MECKLENBURG', 'MIDDLESEX', 'MONTGOMERY', 'NELSON',
#        'NEW KENT', 'NORTHAMPTON', 'NORTHUMBERLAND', 'NOTTOWAY', 'ORANGE',
#        'PAGE', 'PATRICK', 'PITTSYLVANIA', 'POWHATAN', 'PRINCE EDWARD',
#        'PRINCE GEORGE', 'PRINCE WILLIAM', 'PULASKI', 'RAPPAHANNOCK',
#        'RICHMOND', 'ROANOKE', 'ROCKBRIDGE', 'ROCKINGHAM', 'RUSSELL',
#        'SCOTT', 'SHENANDOAH', 'SMYTH', 'SOUTHAMPTON', 'SPOTSYLVANIA',
#        'STAFFORD', 'SURRY', 'SUSSEX', 'TAZEWELL', 'WARREN', 'WASHINGTON',
#        'WESTMORELAND', 'WISE', 'WYTHE', 'YORK', 'ALEXANDRIA CITY',
#        'BRISTOL CITY', 'BUENA VISTA CITY', 'CHARLOTTESVILLE CITY',
#        'CHESAPEAKE CITY', 'COLONIAL HEIGHTS CITY', 'COVINGTON CITY',
#        'DANVILLE CITY', 'EMPORIA CITY', 'FALLS CHURCH CITY',
#        'FREDERICKSBURG CITY', 'GALAX', 'HAMPTON CITY',
#        'HARRISONBURG CITY', 'HOPEWELL', 'LEXINGTON CITY',
#        'LYNCHBURG CITY', 'MANASSAS CITY', 'MANASSAS PARK',
#        'MARTINSVILLE CITY', 'NEWPORT NEWS CITY', 'NORFOLK CITY',
#        'NORTON CITY', 'PETERSBURG CITY', 'POQUOSON CITY',
#        'PORTSMOUTH CITY', 'RADFORD CITY', 'SALEM CITY', 'STAUNTON CITY',
#        'SUFFOLK CITY', 'VIRGINIA BEACH CITY', 'WAYNESBORO CITY',
#        'WILLIAMSBURG CITY', 'WINCHESTER CITY', 'FRANKLIN CITY',
#        'GALAX CITY', 'HOPEWELL CITY', 'MANASSAS PARK CITY',
#        'RICHMOND CITY', 'ROANOKE CITY'], dtype=object)

# %% [markdown]
# Now, we want to combine our results and deal with duplicated values at the same time.

# %%
# cleaned_voting_copy = cleaned_voting.copy()
# combined_voting = cleaned_voting_copy.groupby(
#     ['year', 'county_name', 'county_fips', 'candidate', 'party', 'totalvotes'],
#     as_index=False
# )['candidatevotes'].sum()

# This is the code that should be used to do this, but caused a memory error for some reason, so we will have to do it manually

# %%
cleaned_voting_copy = cleaned_voting.copy()
combinations_unique = cleaned_voting.drop(columns=['candidatevotes']).drop_duplicates()

for idx, row in combinations_unique.iterrows():
    filter = cleaned_voting[
        (cleaned_voting['year'] == row['year']) &
        (cleaned_voting['county_name'] == row['county_name']) &
        (cleaned_voting['county_fips'] == row['county_fips']) &
        (cleaned_voting['candidate'] == row['candidate']) &
        (cleaned_voting['party'] == row['party']) &
        (cleaned_voting['totalvotes'] == row['totalvotes'])
    ]

    combinations_votes = filter['candidatevotes'].sum()
    combined_row = row.copy()
    combined_row['candidatevotes'] = combinations_votes
    cleaned_voting_copy = pd.concat([cleaned_voting_copy, pd.DataFrame([combined_row])], ignore_index=True)

# %%
cleaned_voting_copy
# Out:
#       year        county_name  county_fips          candidate        party  \
# 0     2000           ACCOMACK        51001            AL GORE     DEMOCRAT
# 1     2000           ACCOMACK        51001     GEORGE W. BUSH   REPUBLICAN
# 2     2000           ACCOMACK        51001        RALPH NADER        GREEN
# 3     2000           ACCOMACK        51001              OTHER        OTHER
# 4     2000          ALBEMARLE        51003            AL GORE     DEMOCRAT
# ...    ...                ...          ...                ...          ...
# 6407  2020  WILLIAMSBURG CITY        51830       DONALD TRUMP   REPUBLICAN
# 6408  2020    WINCHESTER CITY        51840  JOSEPH R BIDEN JR     DEMOCRAT
# 6409  2020    WINCHESTER CITY        51840       JO JORGENSEN  LIBERTARIAN
# 6410  2020    WINCHESTER CITY        51840              OTHER        OTHER
# 6411  2020    WINCHESTER CITY        51840       DONALD TRUMP   REPUBLICAN
#
#       candidatevotes  totalvotes
# 0               5092       11925
# 1               6352       11925
# 2                220       11925
# 3                261       11925
# 4              16255       36846
# ...              ...         ...
# 6407            1963        6890
# 6408            6610       12113
# 6409             213       12113
# 6410              69       12113
# 6411            5221       12113
#
# [6412 rows x 7 columns]

# %%
cleaned_voting_copy.to_csv("cleaned_voting.csv",index=False)

# %% [markdown]
# Now that the voting data is cleaned, let's clean the county data

# %%
county_data = pd.read_csv("data/county_adjacencies.csv")
county_data
# Out:
#                County  Population2022   FIPS  District                   N1  \
# 0            Accomack           33191  51001         2       Northumberland
# 1           Albemarle          114534  51003         5  CharlottesvilleCity
# 2      AlexandriaCity          155525  51510         8              Fairfax
# 3           Alleghany           14835  51005         6                Craig
# 4              Amelia           13455  51007         5         PrinceEdward
# ..                ...             ...    ...       ...                  ...
# 128    WinchesterCity           27936  51840         6            Frederick
# 129              Wise           35421  51195         9                  Lee
# 130             Wythe           28111  51197         9                Bland
# 131              York           71341  51199         1           Gloucester
# 132  WilliamsburgCity           15920  51830         1             JamesCty
#
#              N2                N3               N4            N5           N6  \
# 0     Lancaster         Middlesex          Mathews   Northampton          NaN
# 1        Nelson           Augusta       Rockingham        Greene       Orange
# 2     Arlington               NaN              NaN           NaN          NaN
# 3          Bath         Botetourt    CovingtonCity    Rockbridge          NaN
# 4    Cumberland          Powhatan     Chesterfield     Dinwiddie     Nottoway
# ..          ...               ...              ...           ...          ...
# 128         NaN               NaN              NaN           NaN          NaN
# 129       Scott         Dickenson       NortonCity       Russell          NaN
# 130       Smyth           Grayson          Carroll       Pulaski          NaN
# 131    JamesCty  WilliamsburgCity  NewportNewsCity  PoquosonCity  HamptonCity
# 132        York               NaN              NaN           NaN          NaN
#
#               N7        N8          N9     N10  N11  N12
# 0            NaN       NaN         NaN     NaN  NaN  NaN
# 1         Louisa  Fluvanna  Buckingham  Nelson  NaN  NaN
# 2            NaN       NaN         NaN     NaN  NaN  NaN
# 3            NaN       NaN         NaN     NaN  NaN  NaN
# 4            NaN       NaN         NaN     NaN  NaN  NaN
# ..           ...       ...         ...     ...  ...  ...
# 128          NaN       NaN         NaN     NaN  NaN  NaN
# 129          NaN       NaN         NaN     NaN  NaN  NaN
# 130          NaN       NaN         NaN     NaN  NaN  NaN
# 131  Northampton       NaN         NaN     NaN  NaN  NaN
# 132          NaN       NaN         NaN     NaN  NaN  NaN
#
# [133 rows x 16 columns]

# %% [markdown]
# There is very clearly problematic city names, so let's go ahead and fix that:

# %%
county_data['County'] = county_data['County'].str.replace('City', ' City', regex=False).replace('Cty', ' City', regex=False).str.upper()

# Apply specific corrections with a dictionary mapping for known issues
corrections = {
    'BUENAVISTA CITY': 'BUENA VISTA CITY',
    'COLONIALHEIGHTS CITY': 'COLONIAL HEIGHTS CITY',
    'FALLSCHURCH CITY': 'FALLS CHURCH CITY',
    'ISLEOFWIGHT': 'ISLE OF WIGHT',
    'KINGANDQUEEN': 'KING AND QUEEN',
    'KINGGEORGE': 'KING GEORGE',
    'KINGWILLIAM': 'KING WILLIAM',
    'MANASSASPARK CITY': 'MANASSAS PARK CITY',
    'NEWKENT': 'NEW KENT',
    'NEWPORTNEWS CITY': 'NEWPORT NEWS CITY',
    'PRINCEEDWARD': 'PRINCE EDWARD',
    'PRINCEGEORGE': 'PRINCE GEORGE',
    'PRINCEWILLIAM': 'PRINCE WILLIAM',
    'VIRGINIABEACH CITY': 'VIRGINIA BEACH CITY'
}

# Apply corrections
county_data['County'] = county_data['County'].replace(corrections)

# %%
county_data['County'].unique()
# Out:
# array(['ACCOMACK', 'ALBEMARLE', 'ALEXANDRIA CITY', 'ALLEGHANY', 'AMELIA',
#        'AMHERST', 'APPOMATTOX', 'ARLINGTON', 'AUGUSTA', 'BATH', 'BEDFORD',
#        'BLAND', 'BOTETOURT', 'BRISTOL CITY', 'BRUNSWICK', 'BUCHANAN',
#        'BUCKINGHAM', 'BUENA VISTA CITY', 'CAMPBELL', 'CAROLINE',
#        'CARROLL', 'CHARLESCTY', 'CHARLOTTE', 'CHARLOTTESVILLE CITY',
#        'CHESAPEAKE CITY', 'CHESTERFIELD', 'CLARKE',
#        'COLONIAL HEIGHTS CITY', 'COVINGTON CITY', 'CRAIG', 'CULPEPER',
#        'CUMBERLAND', 'DANVILLE CITY', 'DICKENSON', 'DINWIDDIE',
#        'EMPORIA CITY', 'ESSEX', 'FAIRFAX', 'FAIRFAX CITY',
#        'FALLS CHURCH CITY', 'FAUQUIER', 'FLOYD', 'FLUVANNA', 'FRANKLIN',
#        'FRANKLIN CITY', 'FREDERICK', 'FREDERICKSBURG CITY', 'GALAX CITY',
#        'GILES', 'GLOUCESTER', 'GOOCHLAND', 'GRAYSON', 'GREENE',
#        'GREENSVILLE', 'HALIFAX', 'HAMPTON CITY', 'HANOVER',
#        'HARRISONBURG CITY', 'HENRICO', 'HENRY', 'HIGHLAND',
#        'HOPEWELL CITY', 'ISLE OF WIGHT', 'JAMESCTY', 'KING AND QUEEN',
#        'KING GEORGE', 'KING WILLIAM', 'LANCASTER', 'LEE',
#        'LEXINGTON CITY', 'LOUDOUN', 'LOUISA', 'LUNENBURG',
#        'LYNCHBURG CITY', 'MADISON', 'MANASSAS CITY', 'MANASSAS PARK CITY',
#        'MARTINSVILLE CITY', 'MATHEWS', 'MECKLENBURG', 'MIDDLESEX',
#        'MONTGOMERY', 'NELSON', 'NEW KENT', 'NEWPORT NEWS CITY',
#        'NORFOLK CITY', 'NORTHAMPTON', 'NORTHUMBERLAND', 'NORTON CITY',
#        'NOTTOWAY', 'ORANGE', 'PAGE', 'PATRICK', 'PETERSBURG CITY',
#        'PITTSYLVANIA', 'POQUOSON CITY', 'PORTSMOUTH CITY', 'POWHATAN',
#        'PRINCE EDWARD', 'PRINCE GEORGE', 'PRINCE WILLIAM', 'PULASKI',
#        'RADFORD CITY', 'RAPPAHANNOCK', 'RICHMOND', 'RICHMOND CITY',
#        'ROANOKE', 'ROANOKE CITY', 'ROCKBRIDGE', 'ROCKINGHAM', 'RUSSELL',
#        'SALEM CITY', 'SCOTT', 'SHENANDOAH', 'SMYTH', 'SOUTHAMPTON',
#        'SPOTSYLVANIA', 'STAFFORD', 'STAUNTON CITY', 'SUFFOLK CITY',
#        'SURRY', 'SUSSEX', 'TAZEWELL', 'VIRGINIA BEACH CITY', 'WARREN',
#        'WASHINGTON', 'WAYNESBORO CITY', 'WESTMORELAND', 'WINCHESTER CITY',
#        'WISE', 'WYTHE', 'YORK', 'WILLIAMSBURG CITY'], dtype=object)

# %% [markdown]
# It seems that we missed Jamescty and Charlescty, so let's fix that

# %%
additional_corrections = {
    'CHARLESCTY': 'CHARLES CITY',
    'JAMESCTY': 'JAMES CITY'
}

# Apply additional corrections
county_data['County'] = county_data['County'].replace(additional_corrections)

# %%
county_data['County'].unique()
# Out:
# array(['ACCOMACK', 'ALBEMARLE', 'ALEXANDRIA CITY', 'ALLEGHANY', 'AMELIA',
#        'AMHERST', 'APPOMATTOX', 'ARLINGTON', 'AUGUSTA', 'BATH', 'BEDFORD',
#        'BLAND', 'BOTETOURT', 'BRISTOL CITY', 'BRUNSWICK', 'BUCHANAN',
#        'BUCKINGHAM', 'BUENA VISTA CITY', 'CAMPBELL', 'CAROLINE',
#        'CARROLL', 'CHARLES CITY', 'CHARLOTTE', 'CHARLOTTESVILLE CITY',
#        'CHESAPEAKE CITY', 'CHESTERFIELD', 'CLARKE',
#        'COLONIAL HEIGHTS CITY', 'COVINGTON CITY', 'CRAIG', 'CULPEPER',
#        'CUMBERLAND', 'DANVILLE CITY', 'DICKENSON', 'DINWIDDIE',
#        'EMPORIA CITY', 'ESSEX', 'FAIRFAX', 'FAIRFAX CITY',
#        'FALLS CHURCH CITY', 'FAUQUIER', 'FLOYD', 'FLUVANNA', 'FRANKLIN',
#        'FRANKLIN CITY', 'FREDERICK', 'FREDERICKSBURG CITY', 'GALAX CITY',
#        'GILES', 'GLOUCESTER', 'GOOCHLAND', 'GRAYSON', 'GREENE',
#        'GREENSVILLE', 'HALIFAX', 'HAMPTON CITY', 'HANOVER',
#        'HARRISONBURG CITY', 'HENRICO', 'HENRY', 'HIGHLAND',
#        'HOPEWELL CITY', 'ISLE OF WIGHT', 'JAMES CITY', 'KING AND QUEEN',
#        'KING GEORGE', 'KING WILLIAM', 'LANCASTER', 'LEE',
#        'LEXINGTON CITY', 'LOUDOUN', 'LOUISA', 'LUNENBURG',
#        'LYNCHBURG CITY', 'MADISON', 'MANASSAS CITY', 'MANASSAS PARK CITY',
#        'MARTINSVILLE CITY', 'MATHEWS', 'MECKLENBURG', 'MIDDLESEX',
#        'MONTGOMERY', 'NELSON', 'NEW KENT', 'NEWPORT NEWS CITY',
#        'NORFOLK CITY', 'NORTHAMPTON', 'NORTHUMBERLAND', 'NORTON CITY',
#        'NOTTOWAY', 'ORANGE', 'PAGE', 'PATRICK', 'PETERSBURG CITY',
#        'PITTSYLVANIA', 'POQUOSON CITY', 'PORTSMOUTH CITY', 'POWHATAN',
#        'PRINCE EDWARD', 'PRINCE GEORGE', 'PRINCE WILLIAM', 'PULASKI',
#        'RADFORD CITY', 'RAPPAHANNOCK', 'RICHMOND', 'RICHMOND CITY',
#        'ROANOKE', 'ROANOKE CITY', 'ROCKBRIDGE', 'ROCKINGHAM', 'RUSSELL',
#        'SALEM CITY', 'SCOTT', 'SHENANDOAH', 'SMYTH', 'SOUTHAMPTON',
#        'SPOTSYLVANIA', 'STAFFORD', 'STAUNTON CITY', 'SUFFOLK CITY',
#        'SURRY', 'SUSSEX', 'TAZEWELL', 'VIRGINIA BEACH CITY', 'WARREN',
#        'WASHINGTON', 'WAYNESBORO CITY', 'WESTMORELAND', 'WINCHESTER CITY',
#        'WISE', 'WYTHE', 'YORK', 'WILLIAMSBURG CITY'], dtype=object)

# %% [markdown]
# Now let's do the same thing (essentially) but for the N1-N12 columns

# %%
# Define the columns to be reformatted
n_cols = ['N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10', 'N11', 'N12']

# Apply standard formatting to all specified columns
county_data[n_cols] = county_data[n_cols].apply(lambda col: col.str.replace('City', ' City', regex=False).replace('Cty', ' City', regex=False).str.upper())

# Define corrections for specific formatting issues across all these columns
corrections = {
    'BUENAVISTA CITY': 'BUENA VISTA CITY',
    'COLONIALHEIGHTS CITY': 'COLONIAL HEIGHTS CITY',
    'FALLSCHURCH CITY': 'FALLS CHURCH CITY',
    'ISLEOFWIGHT': 'ISLE OF WIGHT',
    'KINGANDQUEEN': 'KING AND QUEEN',
    'KINGGEORGE': 'KING GEORGE',
    'KINGWILLIAM': 'KING WILLIAM',
    'MANASSASPARK CITY': 'MANASSAS PARK CITY',
    'NEWKENT': 'NEW KENT',
    'NEWPORTNEWS CITY': 'NEWPORT NEWS CITY',
    'PRINCEEDWARD': 'PRINCE EDWARD',
    'PRINCEGEORGE': 'PRINCE GEORGE',
    'PRINCEWILLIAM': 'PRINCE WILLIAM',
    'VIRGINIABEACH CITY': 'VIRGINIA BEACH CITY',
    'CHARLESCTY': 'CHARLES CITY',
    'JAMESCTY': 'JAMES CITY'
}

# Apply corrections to all specified columns
county_data[n_cols] = county_data[n_cols].replace(corrections)

# %% [markdown]
# Now let's make sure the column names match up with the column names of the voting data so that they can be merged

# %%
county_data.rename(columns={'County': 'county_name'}, inplace=True)
county_data.rename(columns={'FIPS': 'county_fips'}, inplace=True)
county_data.rename(columns={'Population2022': 'population_2022'}, inplace=True)
county_data.rename(columns={'District': 'district'}, inplace=True)

# %% [markdown]
# Let's make sure we put the county data into its own csv.

# %%
county_data.to_csv("cleaned_county.csv",index=False)

# %% [markdown]
# Now, we can merge the two datasets together

# %%
merged_data = pd.merge(cleaned_voting, county_data, on=['county_name', 'county_fips'], how='inner')
merged_data
# Out:
#       year   county_name  county_fips       candidate       party  \
# 0     2000      ACCOMACK        51001         AL GORE    DEMOCRAT
# 1     2000      ACCOMACK        51001  GEORGE W. BUSH  REPUBLICAN
# 2     2000      ACCOMACK        51001     RALPH NADER       GREEN
# 3     2000      ACCOMACK        51001           OTHER       OTHER
# 4     2004      ACCOMACK        51001      JOHN KERRY    DEMOCRAT
# ...    ...           ...          ...             ...         ...
# 3591  2020  ROANOKE CITY        51770           OTHER       OTHER
# 3592  2020  ROANOKE CITY        51770           OTHER       OTHER
# 3593  2020  ROANOKE CITY        51770    DONALD TRUMP  REPUBLICAN
# 3594  2020  ROANOKE CITY        51770    DONALD TRUMP  REPUBLICAN
# 3595  2020  ROANOKE CITY        51770    DONALD TRUMP  REPUBLICAN
#
#       candidatevotes  totalvotes  population_2022  district              N1  \
# 0               5092       11925            33191         2  NORTHUMBERLAND
# 1               6352       11925            33191         2  NORTHUMBERLAND
# 2                220       11925            33191         2  NORTHUMBERLAND
# 3                261       11925            33191         2  NORTHUMBERLAND
# 4               5518       13356            33191         2  NORTHUMBERLAND
# ...              ...         ...              ...       ...             ...
# 3591              80       43323            97847         6         ROANOKE
# 3592               2       43323            97847         6         ROANOKE
# 3593            7594       43323            97847         6         ROANOKE
# 3594            7856       43323            97847         6         ROANOKE
# 3595             157       43323            97847         6         ROANOKE
#
#       ...         N3       N4           N5   N6   N7   N8   N9  N10  N11  N12
# 0     ...  MIDDLESEX  MATHEWS  NORTHAMPTON  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     ...  MIDDLESEX  MATHEWS  NORTHAMPTON  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2     ...  MIDDLESEX  MATHEWS  NORTHAMPTON  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3     ...  MIDDLESEX  MATHEWS  NORTHAMPTON  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4     ...  MIDDLESEX  MATHEWS  NORTHAMPTON  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...   ...        ...      ...          ...  ...  ...  ...  ...  ...  ...  ...
# 3591  ...        NaN      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3592  ...        NaN      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3593  ...        NaN      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3594  ...        NaN      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3595  ...        NaN      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [3596 rows x 21 columns]

# %%
merged_data.to_csv("merged_data.csv",index=False)
